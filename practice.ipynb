# %%
print('we are live')
# Out:
# we are live

# %%
1 == 2
# Out:
# False

# %%
'2' == 3
# Out:
# False

# %%
'2' != 3
# Out:
# True

# %%
(2 == '2') and (2 < 3)
# Out:
# False

# %%
# !git init
# Out:
# Initialized empty Git repository in /Users/macbookair/Downloads/.git/

# %%
# !git add "practice.ipynb"

# %%
# !git commit -m "practicing python"
# Out:
# [main (root-commit) cd59ffe] practicing python
#  1 file changed, 143 insertions(+)
#  create mode 100644 practice.ipynb

# %%
# !git remote add origin https://github.com/gabzy-dev/pythonpractice.git

# %%
# !git push -u origin main
# Out:
# Enumerating objects: 3, done.
# Counting objects: 100% (3/3), done.
# Delta compression using up to 8 threads
# Compressing objects: 100% (2/2), done.
# Writing objects: 100% (3/3), 909 bytes | 454.00 KiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# To https://github.com/gabzy-dev/pythonpractice.git
#  * [new branch]      main -> main
# branch 'main' set up to track 'origin/main'.

# %%
400 > 300
# Out:
# True

# %%
not 400 > 300
# Out:
# False

# %%
not 100 > 300
# Out:
# True

# %%
if 3 > 1:
    print('its greater')
else:
    print('its lesser')
# Out:
# its greater

# %%
location = 'lithuania'
if location == 'london':
    print('my location is london')
elif location == 'coventry':
    print('yes!,i am in coventry')
elif location == 'lithuania':
    print('i am in lithuania')
else:
    print('specify your location,please.')
# Out:
# i am in lithuania

# %%
my_biglist= [1,5,7,8,3,9]
for digits in my_biglist:
    print(digits)
# Out:
# 1
# 5
# 7
# 8
# 3
# 9

# %%
# !git add practice.ipynb
